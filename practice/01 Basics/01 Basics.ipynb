# %% [markdown]
# # Анализ и прогнозирование временных рядов методами искусственного интеллекта
#
# ## **Практическая работа 1. Метрики и меры схожести между временными рядами.**

# %% [markdown]
# Смените рабочую директорию с помощью команды `chdir()`. Для этого передайте этой команде свой путь до каталога, в котором содержатся материалы первой практической работы. После выполнения этой команды все последующие операции с файлами и каталогами будут производиться относительно указанного каталога.

# %%
'''
import os

practice_dir_path = 'C:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics'
os.chdir(practice_dir_path)
'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Phoenix\AppData\Local\Temp\ipykernel_30940\1512984542.py:1: SyntaxWarning: invalid escape sequence '\p'
#   '''
# "\nimport os\n\npractice_dir_path = 'C:\x825-NAzarchuk-TimeSeriesCourse\\practice\x01 Basics'\nos.chdir(practice_dir_path)\n"

# %% [markdown]
# Выполните команды, которые автоматически перезагружают все импортированные модули при их изменении.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Импортируйте библиотеки и модули, необходимые для реализации практической работы 1.

# %%
# !pip install sktime
# Out:
# Collecting sktime
#   Using cached sktime-0.39.0-py3-none-any.whl.metadata (32 kB)
# Collecting joblib<1.6,>=1.2.0 (from sktime)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: numpy<2.4,>=1.21 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from sktime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from sktime) (24.2)
# Requirement already satisfied: pandas<2.4.0,>=1.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from sktime) (2.2.3)
# Collecting scikit-base<0.13.0,>=0.6.1 (from sktime)
#   Using cached scikit_base-0.12.6-py3-none-any.whl.metadata (8.8 kB)
# Collecting scikit-learn<1.8.0,>=0.24 (from sktime)
#   Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting scipy<2.0.0,>=1.2 (from sktime)
#   Using cached scipy-1.16.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.4.0,>=1.1->sktime) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.4.0,>=1.1->sktime) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from pandas<2.4.0,>=1.1->sktime) (2024.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<1.8.0,>=0.24->sktime)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.4.0,>=1.1->sktime) (1.17.0)
# Downloading sktime-0.39.0-py3-none-any.whl (35.6 MB)
#    ---------------------------------------- 0.0/35.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/35.6 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/35.6 MB 12.5 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.4/35.6 MB 22.6 MB/s eta 0:00:02
#    -------------------- ------------------- 17.8/35.6 MB 28.8 MB/s eta 0:00:01
#    ------------------------------ --------- 26.7/35.6 MB 32.6 MB/s eta 0:00:01
#    -------------------------------------- - 34.6/35.6 MB 33.3 MB/s eta 0:00:01
#    ---------------------------------------- 35.6/35.6 MB 31.8 MB/s eta 0:00:00
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached scikit_base-0.12.6-py3-none-any.whl (149 kB)
# Using cached scikit_learn-1.7.2-cp312-cp312-win_amd64.whl (8.7 MB)
# Using cached scipy-1.16.2-cp312-cp312-win_amd64.whl (38.6 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-base, joblib, scikit-learn, sktime
# Successfully installed joblib-1.5.2 scikit-base-0.12.6 scikit-learn-1.7.2 scipy-1.16.2 sktime-0.39.0 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install imutils opencv-python matplotlib
# Out:
# Requirement already satisfied: imutils in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Requirement already satisfied: opencv-python in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: matplotlib in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (3.10.6)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\phoenix\appdata\roaming\python\python312\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\phoenix\appdata\roaming\python\python312\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\phoenix\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4
#    ------------------------------------ --- 8.9/9.8 MB 77.4 kB/s eta 0:00:12
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    ------------------------------------- -- 9.2/9.8 MB 80.2 kB/s eta 0:00:09
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    -------------------------------------- - 9.4/9.8 MB 84.5 kB/s eta 0:00:05
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------  9.7/9.8 MB 87.9 kB/s eta 0:00:02
#    ---------------------------------------- 9.8/9.8 MB 87.9 kB/s eta 0:00:00
# Downloading narwhals-2.6.0-py3-none-any.whl (408 kB)
# Installing collected packages: narwhals, plotly
# Successfully installed narwhals-2.6.0 plotly-6.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import random
from sktime.distances import euclidean_distance, dtw_distance, pairwise_distance
from sklearn.metrics import silhouette_score
import cv2
import imutils
import glob
import matplotlib.pyplot as plt
#from google.colab.patches import cv2_imshow

from modules.metrics import ED_distance, norm_ED_distance, DTW_distance
from modules.pairwise_distance import PairwiseDistance
from modules.clustering import TimeSeriesHierarchicalClustering
from modules.classification import TimeSeriesKNN, calculate_accuracy
from modules.image_converter import Image2TimeSeries
from modules.utils import read_ts, z_normalize, sliding_window, random_walk
from modules.plots import plot_ts
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>

# %% [markdown]
# ## **Часть 1.** Функции расстояния: евклидова метрика и DTW мера. Матрица расстояний. Иерархическая кластеризация временных рядов.

# %% [markdown]
# ### **Задача 1.**
# Реализуйте самостоятельно функцию `ED_distance()` в модуле *metrics.py*, которая вычисляет евклидово расстояние между двумя временными рядами, имеющими одинаковую длину. В качестве входных данных передайте в функцию два синтетических временных ряда некоторой заданной вами длины. Для их генерации используйте функцию `random_walk()` из модуля *utils.py*,  реализующую модель случайных блужданий (Random Walk), или стандартный модуль *random*.
#
# **Евклидово расстояние** между двумя временными рядами $T_1$ и $T_2$ длины $n$ вычисляется следующим образом:
#
# \begin{equation}
#     \text{ED}(T_1, T_2) = \sqrt{\sum_{i=1}^{n} ({t_{1}}_i-{t_{2}}_i)^2}.
# \end{equation}
#
# Проверьте реализацию функции, сравнив свои результаты с результатами функции [`euclidean_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.euclidean_distance.html) из библиотеки *sktime*, с помощью `test_distances()`.

# %%
def test_distances(dist1: float, dist2: float) -> None:
    """
    Check whether your distance function is implemented correctly

    Parameters
    ----------
    dist1 : distance between two time series calculated by sktime
    dist2 : distance between two time series calculated by your function
    """

    np.testing.assert_equal(round(dist1, 5), round(dist2, 5), 'Distances are not equal')

# %%
ts1 = random_walk(100)
ts2 = random_walk(100)

# %%
my_dist = ED_distance(ts1, ts2)
print(f"Расстояние, вычисленное вашей функцией: {my_dist}")

sktime_dist = euclidean_distance(ts1, ts2)
print(f"Расстояние, вычисленное sktime:        {sktime_dist}")
# Out:
# Расстояние, вычисленное вашей функцией: 90.92854337335444
# Расстояние, вычисленное sktime:        90.92854337335444

# %% [markdown]
# ### **Задача 2.**
#
# Реализуйте самостоятельно функцию `DTW_distance()` в модуле *metrics.py*, которая вычисляет DTW расстояние между двумя временными рядами, имеющими одинаковую длину. Для вычисления расстояния между элементами временных рядов в DTW мере используйте евклидово расстояние. Временные ряды сгенерируйте аналогичным образом, как в задаче 1, или используйте уже созданные.
#
# **Динамическая трансформация временной шкалы (Dynamic Time Warping, DTW)** – мера схожести между двумя временными рядами $T_1$ и $T_2$ длины $n$, вычисляемая следующим образом:
#
# \begin{equation}
# \text{DTW}(T_1, T_2) = d(n,n),
# \\ d(i,j) = ({t_{1}}_i - {t_{2}}_j)^2 + \min \left\{
# 	\begin{array}{l l}
# 	d(i-1,j), \\
# 	d(i,j-1), \\
# 	d(i-1,j-1),
# 	\end{array}
# 	\right.
# \\ d(0,0)=0, \quad d(i,0)=d(0,j)=\infty, \quad  1 \leqslant i,j \leqslant n.
# \end{equation}
#
# Сравните свои результаты с результатами функции [`dtw_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.dtw_distance.html) из библиотеки *sktime*. Для этого используйте `test_distances()` из задачи 1.

# %%
my_dtw_dist = DTW_distance(ts1, ts2)
print(f"DTW расстояние, вычисленное вашей функцией: {my_dtw_dist}")


sktime_dtw_dist = dtw_distance(ts1, ts2)
print(f"DTW расстояние, вычисленное sktime:        {sktime_dtw_dist}")
# Out:
# DTW расстояние, вычисленное вашей функцией: 4714.0
# DTW расстояние, вычисленное sktime:        4714.0

# %% [markdown]
# ### **Задача 3.**
# Реализуйте нахождение матрицы расстояний между несколькими временными рядами.
# Для этого заполните все методы c недостающим кодом в классе `PairwiseDistance` из модуля *pairwise_distance.py*. Для вычисления расстояний между рядами используйте ранее реализованные вами функции `ED_distance()` и `DTW_distance()` из модуля *metrics.py*.
#
# Матрица расстояний между временными рядами определяется следующим образом. Пусть дано множество $S$, состоящее из $K$ временных рядов длины $n$: $\;S = \{T_1, T_2, ..., T_K\}, \; T_i \in \mathbb{R}^n$. Тогда под **матрицей расстояний** $D \in \mathbb{R}^{K \times K}$ понимается квадратная матрица, где каждый ее элемент $d(i,j)$ представляет собой расстояние между временными рядами $T_i$ и $T_j$ из множества $S$:
# \begin{equation}
# d(i,j) = dist(T_i, T_j), \quad T_i, T_j \in S, \quad 1 \leqslant i,j \leqslant K.
# \end{equation}
#
# Поскольку евклидова метрика и DTW мера удовлетворяют аксиоме симметричности (т.е. $dist(T_i, T_j)=dist(T_j, T_i)$), то матрица расстояний $D$ будет симметричной относительно главной диагонали. Для ускорения вычислений достаточно найти ее верхний треугольник, а нижний треугольник матрицы заполнить значениями верхнего треугольника следующим образом:
# \begin{equation}
# d(j,i) = d(i,j), \; где \; i < j.
# \end{equation}
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/distance_matrix.png?raw=true" width="600"></center>

# %% [markdown]
# Сгенерируйте множество, состоящее из $K$ временных рядов некоторой длины $n$. Вычислите матрицы евклидовых и DTW расстояний между ними. Проверьте реализованные вами методы, сравнив свои результаты с результатами функции [`pairwise_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.pairwise_distance.html) из библиотеки *sktime*.

# %%
def test_matrices(matrix1 : np.ndarray, matrix2 : np.ndarray) -> None:
    """
    Check whether your matrix function is implemented correctly

    Parameters
    ----------
    matrix1 : distance matrix calculated by sktime
    matrix2 : distance matrix calculated by your function
    """

    np.testing.assert_equal(matrix1.round(5), matrix2.round(5), 'Matrices are not equal')

# %%
K = 5  # количество рядов
n = 50 # длина каждого ряда
ts_set = np.array([random_walk(n) for _ in range(K)])

# %%
print("--- Проверка для Евклидовой метрики ---")

pairwise_ed = PairwiseDistance(metric='euclidean')
my_ed_matrix = pairwise_ed.calculate(ts_set) 
print("Матрица, посчитанная классом:\n", my_ed_matrix.round(2))

sktime_ed_matrix = pairwise_distance(ts_set, metric='euclidean')
print("\nМатрица, посчитанная sktime:\n", sktime_ed_matrix.round(2))

test_matrices(sktime_ed_matrix, my_ed_matrix)
print("\nМатрицы равны (скорее всего)!")
# Out:
# --- Проверка для Евклидовой метрики ---
# Матрица, посчитанная классом:
#  [[  0.    46.56  15.36  19.08 111.18]
#  [ 46.56   0.    53.7   45.39  71.11]
#  [ 15.36  53.7    0.    26.98 114.07]
#  [ 19.08  45.39  26.98   0.   113.23]
#  [111.18  71.11 114.07 113.23   0.  ]]
#
# Матрица, посчитанная sktime:
#  [[  0.    46.56  15.36  19.08 111.18]
#  [ 46.56   0.    53.7   45.39  71.11]
#  [ 15.36  53.7    0.    26.98 114.07]
#  [ 19.08  45.39  26.98   0.   113.23]
#  [111.18  71.11 114.07 113.23   0.  ]]
#
# Матрицы равны (скорее всего)!

# %%
print("\n\n--- Проверка для DTW метрики ---")


pairwise_dtw = PairwiseDistance(metric='dtw')
my_dtw_matrix = pairwise_dtw.calculate(ts_set) 
print("Матрица, посчитанная написанным классом:\n", my_dtw_matrix.round(2))

sktime_dtw_matrix = pairwise_distance(ts_set, metric='dtw')
print("\nМатрица, посчитанная sktime:\n", sktime_dtw_matrix.round(2))

test_matrices(sktime_dtw_matrix, my_dtw_matrix)
print("\nМатрицы равны (скорее всего)!")
# Out:
# --- Проверка для DTW метрики ---
# Матрица, посчитанная написанным классом:
#  [[    0.  1258.    58.    46. 11333.]
#  [ 1258.     0.  1734.  1406.  3224.]
#  [   58.  1734.     0.    56. 10716.]
#  [   46.  1406.    56.     0. 12792.]
#  [11333.  3224. 10716. 12792.     0.]]
#
# Матрица, посчитанная sktime:
#  [[    0.  1258.    58.    46. 11333.]
#  [ 1258.     0.  1734.  1406.  3224.]
#  [   58.  1734.     0.    56. 10716.]
#  [   46.  1406.    56.     0. 12792.]
#  [11333.  3224. 10716. 12792.     0.]]
#
# Матрицы равны (скорее всего)!

# %% [markdown]
# ### **Задача 4.**
# Далее рассмотрим задачу иерархической кластеризации временных рядов, где будет использоваться предвычисленная матрица расстояний.
#
# Для этого сначала загрузите набор временных рядов CBF из файла *CBF_TRAIN.txt*, который располагается в директории *./datasets/part1*. Каждая строка данного файла содержит целевую переменную (класс: 0, 1 или 2) в первом столбце и временной ряд в остальных столбцах. Набор CBF является синтетическим и включает в себя 30 временных рядов,  каждый из которых принадлежит к одному из трех классов.

# %%
url = './datasets/part1/CBF_TRAIN.txt'
data = read_ts(url)

ts_set = data[:, 1:]

labels = data[:, 0].astype(int)

print("Уникальные метки в файле:", np.unique(labels))
# Out:
# Уникальные метки в файле: [1 2 3]
# c:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics\modules\utils.py:20: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %% [markdown]
# Выполните визуализацию по одному временному ряду из каждого класса. Для этого используйте функцию `plot_ts()` из модуля *plots.py*.

# %%
ts_class_1 = ts_set[np.where(labels == 1)[0][0]]
ts_class_2 = ts_set[np.where(labels == 2)[0][0]]
ts_class_3 = ts_set[np.where(labels == 3)[0][0]]


ts_to_plot = np.array([ts_class_1, ts_class_2, ts_class_3])


plot_labels = [1, 2, 3]
plot_titles = [f"Class {l}" for l in plot_labels]


fig = plot_ts(ts_to_plot)
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="c53e1009-80a4-4e03-8a2a-8ab03ae371fe" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c53e1009-80a4-4e03-8a2a-8ab03ae371fe")) {                    Plotly.newPlot(                        "c53e1009-80a4-4e03-8a2a-8ab03ae371fe",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i4","bdata":"..."},"y":{"dtype":"f8","bdata":"x4E2vbS23b+nqSvA88Lhv6MYxReS+Oq\u002fylULcGq1679HcfFk9fbtvyAdaE8TJ+q\u002fbsmBiQXf0L9GnRRB9yD0v+AlgoKcAfS\u002fKbSs+8di7b\u002fokEiZ3IHtvzmmvJDtgO+\u002frTpheNub9L\u002fri4S2nEvyv9G+qJMiyPC\u002f\u002fJ3UNHti179rkJPT6B\u002fmvz21+uqqYO+\u002fFYLJSwa5
L8fwlMjT83yv4eMBY2yYdu\u002fAMBWrlw0879RiSXE4Mriv+YetwSFxvK\u002fIfgIyqdm1L96CQTwBVz7v6pQk8\u002fhEPu\u002foxS+CGTg8L9MfWoGAk71vzpRGoOxEua\u002fuPiIVvbW57+m6HGtMHzvvySBBps6D\u002fO\u002fl\u002fVqmW+R4b+THdlkprfiP+Nmn2T+8+K\u002fo6lDE81o6L9hFZByBxzSv2o74JlU3du\u002fmJLds0snwD+EN\u002feZqw3VvxssnKT5Q\u002fe\u002fPZBIHRXm4L91BGv6vki3vw+riU9LPbQ\u002fsq+G1WlO8r8WJGwu7Yrwv8aPShTOLN2\u002fiplUn3Ei4b+0ABLy5hXBv7L0whnT\u002fs2\u002fXNrb8x14qj\u002febFrG2XbmP6AXzU4vRs4\u002fUjQo\u002fTHr3D+HlJfjsh3nv+irmtZc5PO\u002fyBUP1pyP3T\u002fgOCFbMwXhP6EmfrU4Hdc\u002fnEh\u002fG6Egoj9qCDuDji\u002fUP5fvbNH6QuE\u002fv6Qp6f49xz8GZBKiOmXYv0AxZtZIzqO\u002ftuHq33my4j\u002f5DZdF9rvUvwv0fBJHOp0\u002f1FO7kT85vL+bokw4LkK3v781h9ZQC9Y\u002fv6a9d4rL0j8dwEs+sKLoP6Ueu26+j90\u002f7I6ct3du0D8nAFpOnaLyP\u002fMobHFTxOM\u002fn3r\u002feuC+zr8RTLnrOo7lP9tCoa9q2so\u002f6PO0cBcJ6D\u002fQ9kPHaePwP+PxcN\u002fDVZS\u002fYSqJLqB+2j9578HOwZHuP\u002fZXuHqIZdM\u002f9qhsFjcHzT9pBkw7kFD0P7LJKyFpYfA\u002fnu4b47OK4z\u002fg7pNA1hXkP67YgIQ4wek\u002fgrEZOzwf9D\u002fnv+4Rvc7RP6kbg6nBL\u002fA\u002fF+vA3mlX7j8+MfzxqAL1P0rH5vQG6fA\u002fHOws\u002ft\u002fG6z\u002fLCiwd\u002f4flP+ghCbHpt\u002fI\u002f\u002fYv76gU6AUCDC8ORUa\u002f7P+eSBaeZafw\u002fK7qa4asC9T9x1 ...

# %% [markdown]
# Далее самостоятельно реализуйте класс `TimeSeriesHierarchicalClustering` из модуля *clustering.py*, который выполняет иерархическую кластеризацию временных рядов.
#
# Перед тем как приступить к реализации, изучите скелет этого класса. Реализуйте метод `fit()`, выполняющий кластеризацию данных на основе предвычисленной матрицы расстояний, которая передается в данный метод. Поскольку реализовать иерархическую кластеризацию довольно сложно, используйте готовую реализацию [`AgglomerativeClustering`](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html) из *sklearn*.
#
# Выполните иерархическую кластеризацию загруженных временных рядов CBF для двух функций расстояния: евлидовой метрики и DTW меры.
# Для этого сначала найдите матрицы расстояний между временными рядами, используя класс `PairwiseDistance`, и передайте каждую матрицу в метод `fit()` для кластеризации.
# Далее выполните визуализацию результатов в виде дендрограмм с помощью метода `plot_dendrogram()`, передав исходный набор временных рядов и их метки.

# %% [markdown]
# Сравните результаты иерархической кластеризации, полученные при двух различных функций расстояния, с помощью силуэтного коэффициента. Для этого используйте функцию [`silhouette_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html) из библиотеки *sklearn*, передав в нее предвычисленную матрицу расстояний и предсказанные метки.
#
# **Силуэтный коэффициент** – метрика, которая оценивает качество кластеризации на основе исходной выборки и результатов кластеризации без необходимости знания об истинных метках объектов.
#
# Силуэтный коэффициент для выборки показывает, насколько среднее расстояние до объектов своего кластера отличается от среднего расстояния до объектов других кластеров. Пусть дана выборка $X$, состоящая из $N$ объектов. Предположим, что объекты этой выборки были разбиты на кластеры $c_1, ... c_K$, $c_i \in C$, с помощью некоторого алгоритма кластеризации. Тогда силуэтный коэффициент для выборки будет вычисляться следующим образом:
#
# \begin{equation}
# sil\_coef = \frac{1}{N} \sum_{c_k \in C} \sum_{x_i \in c_k} \frac{b(x_i, c_k) - a(x_i, c_k)}{\max(a(x_i, c_k), b(x_i, c_k))},
# \end{equation}
#
# где $a(x_i, c_k)$ – среднее расстояние от объекта $x_i \in c_k$ до других объектов из этого же кластера $c_k$; <br> $b(x_i, c_k)$  – среднее расстояние от объекта $x_i \in c_k$ до объектов из другого кластера $c_l$, $k \neq l$.
#
# Силуэтный коэффициент принимает значения от  −1  до  1:
# *   –1 означает, что кластеры плохие, размытые;
# *   0 означает, что кластеры накладываются друг на друга;
# *   1 означает, что кластеры плотные и хорошо отделены друг от друга.
#
# Таким образом, чем ближе значение коэффициента к 1, тем лучше кластеризованы данные.

# %%
# !pip install typing_extensions
# Out:
# Requirement already satisfied: typing_extensions in c:\users\phoenix\appdata\local\programs\python\python312\lib\site-packages (4.12.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
print("--- Кластеризация с Евклидовой метрикой ---")


pairwise_ed = PairwiseDistance(metric='euclidean')
ed_matrix = pairwise_ed.calculate(ts_set)


h_clustering_ed = TimeSeriesHierarchicalClustering(n_clusters=3, method='complete')
h_clustering_ed.fit(ed_matrix)

print("Дендрограмма для Евклидовой метрики:")
df_ts = pd.DataFrame(ts_set)
h_clustering_ed.plot_dendrogram(df_ts, labels, title='Dendrogram (Euclidean)')



print("\n--- Кластеризация с DTW ---")


pairwise_dtw = PairwiseDistance(metric='dtw')
dtw_matrix = pairwise_dtw.calculate(ts_set)


h_clustering_dtw = TimeSeriesHierarchicalClustering(n_clusters=3, method='complete')
h_clustering_dtw.fit(dtw_matrix)


print("Дендрограмма для DTW:")
h_clustering_dtw.plot_dendrogram(df_ts, labels, title='Dendrogram (DTW)')
# Out:
# --- Кластеризация с Евклидовой метрикой ---
# Дендрограмма для Евклидовой метрики:
#
# --- Кластеризация с DTW ---
# Дендрограмма для DTW:

# %%
score_ed = silhouette_score(ed_matrix, h_clustering_ed.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент для Евклидовой метрики: {score_ed:.4f}")


score_dtw = silhouette_score(dtw_matrix, h_clustering_dtw.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент для DTW: {score_dtw:.4f}")
# Out:
# Силуэтный коэффициент для Евклидовой метрики: 0.1804
# Силуэтный коэффициент для DTW: 0.3881

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте полученные результаты кластеризации с помощью построенных дендрограмм и вычисленных силуэтных коэффициентов. Какая, на ваш взгляд, функция расстояния показала лучший результат и почему? Укажите, в каких случаях более предпочтительно использовать DTW меру, чем евклидову метрику.

# %% [markdown]
# Анализ результатов (на основе ваших данных)
# 1. Какая функция расстояния показала лучший результат?
# DTW мера показала значительно лучший результат. Силуэтный коэффициент для DTW (0.3881) более чем в два раза превышает коэффициент для евклидовой метрики (0.1804). Это говорит о том, что кластеры, полученные с помощью DTW, являются более плотными (объекты внутри кластера похожи друг на друга) и лучше отделены друг от друга (объекты из разных кластеров сильно отличаются), чем кластеры, полученные с помощью евклидовой метрики.
# 2. Почему так произошло?
# Евклидово расстояние (0.1804): Такое низкое значение говорит о том, что кластеры получились "размытыми" и, возможно, накладываются друг на друга. Этот метод сравнивает значения временных рядов в каждой точке времени "один к одному". Если формы рядов похожи, но один из них немного сдвинут или растянут во времени, евклидово расстояние посчитает их очень непохожими.
# DTW (0.3881): Значение почти 0.4 — это уже заметно лучше. DTW способен находить оптимальное "выравнивание" между двумя временными рядами, игнорируя небольшие сдвиги и деформации по оси времени. Для датасета CBF, где ряды в одном классе имеют схожую общую форму (цилиндр, колокол или воронка), но могут немного различаться по фазе, эта гибкость DTW является решающим преимуществом.
# 3. В каких случаях предпочтительно использовать DTW?
# DTW меру следует использовать, когда важна общая форма (паттерн) временного ряда, а не его точное положение во времени. Евклидова метрика, наоборот, подходит для случаев, когда важна синхронность и точное совпадение значений в каждый момент времени.
# Предпочтение DTW:
# Анализ биомедицинских сигналов (ЭКГ, ЭЭГ): Форма сердечного ритма важнее его точного момента начала.
# Распознавание жестов или подписей: Движение может быть выполнено быстрее или медленнее, но общая траектория остается той же.
# Сравнение аудиосигналов (например, речи): Скорость произношения слов варьируется.
# Финансовые рынки: Поиск схожих паттернов цен (например, "голова и плечи"), которые могут формироваться за разное время.
# Предпочтение Евклидовой метрике:
# Сравнение показаний откалиброванных сенсоров: Если два датчика должны показывать одно и то же в один и тот же момент времени, и любое расхождение является аномалией.
# Контроль качества в производстве: Когда форма изделия в каждый момент времени должна строго соответствовать эталону.

# %% [markdown]
# ## **Часть 2.** $Z$-нормализация временных рядов.

# %% [markdown]
# ### **Задача 5.**
# Реализуйте функцию вычисления нормализованного евклидова расстояния между временными рядами `norm_ED_distance()` в модуле *metrics.py* и проверьте правильность своей реализации, сравнив полученные результаты с результатами функции [`ed_distance()`](https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.distances.euclidean_distance.html) из библиотеки *sktime*, в которую необходимо передать <u>нормализованные</u> временные ряды. Для нормализации временных рядов используйте функцию `z-normalize()` из *utils.py*.  Для проверки можно использовать синтетические временные ряды из первой части или заново их сгенерировать.
#
# **Нормализованная евклидова метрика** между двумя временными рядами $T_1$ и $T_2$ длины $n$ вычисляется следующим образом:
#
# \begin{equation}
# 	\text{ED}_{norm}(T_1, T_2) = \sqrt {\Big|\; 2n\left(1-\dfrac{<T_1, T_2> - \; n \; \cdotp \mu_{T_1} \; \cdotp \mu_{T_2}}{n \; \cdotp \sigma_{T_1} \; \cdotp \sigma_{T_2}}\right)\Big|},
# \end{equation}
#
# где $<T_1, T_2>$ – скалярное произведение временных рядов, $\mu_{T_1}$ и $\mu_{T_2}$, $\sigma_{T_1}$ и $\sigma_{T_2}$ – среднее арифметическое и стандартное отклонение временных рядов соответственно.
#
# **Среднее арифметическое** $\mu_T$ и **стандартное отклонение** $\sigma_T$ временного ряда $T$ длины $n$ вычисляются по следующим формулам:
#
# \begin{equation}
# 	\mu_{T} = \frac{1}{n}\sum\limits_{i=1}^{n} t_{i}, \\[1em]
# 	\sigma_{T} = \sqrt{\frac{1}{n}\sum\limits_{i=1}^{n} t_i^2-\mu_{T}^2}.
# \end{equation}

# %%
ts1_raw = random_walk(100) * 10 + 50  
ts2_raw = random_walk(100) * 2 - 10   


my_norm_dist = norm_ED_distance(ts1_raw, ts2_raw)
print(f"Нормализованное расстояние (ваша функция): {my_norm_dist:.4f}")

ts1_norm_check = z_normalize(ts1_raw)
ts2_norm_check = z_normalize(ts2_raw)
sktime_norm_dist = euclidean_distance(ts1_norm_check, ts2_norm_check)
print(f"Нормализованное расстояние (sktime):       {sktime_norm_dist:.4f}")

test_distances(sktime_norm_dist, my_norm_dist)
print("\nВсе верное.")
# Out:
# Нормализованное расстояние (ваша функция): 18.1386
# Нормализованное расстояние (sktime):       18.1386
#
# Все верное.

# %% [markdown]
# ### **Задача 6.**
# Далее убедимся, что выполнение $z$-нормализации на этапе предобработки данных имеет важное значение и может повысить точность решаемой задачи.
#
# В данном задании вы продолжите решать задачу иерархической кластеризации. В качестве данных будут использоваться два временных ряда из набора данных [BIDMC](https://physionet.org/content/chfdb/1.0.0/). Набор BIDMC состоит из записей ЭКГ-сигналов, снятых с 15 пациентов с сердечной недостаточностью тяжелой степени.
#
# Загрузите два временных ряда и визуализируйте их с помощью функции `plot_ts()` из модуля *plots.py*.

# %%
url1 = './datasets/part2/chf10.csv'
ts1 = read_ts(url1)

url2 = './datasets/part2/chf11.csv'
ts2 = read_ts(url2)
# Out:
# c:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics\modules\utils.py:20: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#
# c:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics\modules\utils.py:20: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %%
ts_set = np.concatenate((ts1, ts2), axis=1).T

# %%
plot_ts(ts_set)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="480d08ff-80a1-4581-880f-c6f714ca74d6" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("480d08ff-80a1-4581-880f-c6f714ca74d6")) {                    Plotly.newPlot(                        "480d08ff-80a1-4581-880f-c6f714ca74d6",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i4","bdata":"...\\u002fAAAAP0AAAD+AAAA\...\...\\...\u002fQIAAP4CAAD\...\\u002fAMAAP0DAAD+AwAA\...\...\\...\u002fQUAAP4FAAD\...\\u002fAYAAP0GAAD+BgAA\...\...\\...\u002fQgAAP4IAAD\...\\u002fAkAAP0JAAD+CQAA\...\...\\..."},"y":{"dtype":"f8","bdata":"CtejcD0Kx79mZmZmZmbGv2ZmZmZmZsa\u002fw\u002fUoXI\u002fCxb\u002fD9Shcj8LFv8P1KFyPwsW\u002fCtejcD0Kx7+amZmZmZnJv2ZmZmZmZsa\u002fH4XrUbgexb89CtejcD3Kv1K4HoXrUci\u002fKVyPwvUozL\u002fhehSuR+HKvylcj8L1KMy\u002fuB6F61G4zr9SuB6F61HQv5qZmZmZmdG\u002f9ihcj8L10L9I4XoUrkfRv6RwPQrXo9C\u002f7FG4HoXr0b\u002f2KFyPwvXQv+xRuB6F69G\u002f9ihcj8L10L9I4XoUrkfRv5qZmZm ...

# %% [markdown]
# Разделите каждый временной ряд на непересекающиеся подпоследовательности с помощью техники скользящего окна. Для этого используйте функцию `sliding_window()` из модуля *utils.py*, передав в нее временной ряд, заданную длину подпоследовательности и величину шага. В нашем случае, величина шага равна длине подпоследовательности.

# %%
m = 125
subs_set1 = sliding_window(ts_set[0], m, m-1)
subs_set2 = sliding_window(ts_set[1], m, m-1)

# %% [markdown]
# Сформируйте множество всех подпоследовательностей, извлеченных из двух временных рядов, и массив меток подпоследовательностей в соответствии с их принадлежностью к временному ряду.

# %%
subs_set = np.concatenate((subs_set1[0:15], subs_set2[0:15]))
labels = np.array([0]*subs_set1[0:15].shape[0] + [1]*subs_set2[0:15].shape[0])

# %% [markdown]
# Добавьте в класс `PairwiseDistance` из модуля *pairwise_distance.py* возможность вычисления нормализованной евклидовой метрики между временными рядами. Если матрица расстояний строится для нормализованных временных рядов на основе евклидовой метрики, то должна вызываться функция `norm_ED_distance()`. Для остальных метрик/мер схожести перед нахождением матрицы расстояний временные ряды должны подтвергаться $z$-нормализации с помощью функции `z_normalize()` из модуля *utils.py*.
#
# Далее выполните иерархическую кластеризацию подпоследовательностей двух временных рядов с использованием предварительно построенных матриц расстояний на основе классической и нормализованной евклидовой метрики.

# %%
print("--- Кластеризация БЕЗ нормализации ---")


pairwise_ed_raw = PairwiseDistance(metric='euclidean')
ed_matrix_raw = pairwise_ed_raw.calculate(subs_set)


h_clustering_raw = TimeSeriesHierarchicalClustering(n_clusters=2, method='complete')
h_clustering_raw.fit(ed_matrix_raw)


df_subs = pd.DataFrame(subs_set)
h_clustering_raw.plot_dendrogram(df_subs, labels, title='Dendrogram (Raw Data)')
# Out:
# --- Кластеризация БЕЗ нормализации ---

# %%
print("\n--- Кластеризация С нормализацией ---")


pairwise_ed_norm = PairwiseDistance(metric='euclidean', is_normalize=True)
ed_matrix_norm = pairwise_ed_norm.calculate(subs_set)


h_clustering_norm = TimeSeriesHierarchicalClustering(n_clusters=2, method='complete')
h_clustering_norm.fit(ed_matrix_norm)


h_clustering_norm.plot_dendrogram(df_subs, labels, title='Dendrogram (Normalized Data)')
# Out:
# --- Кластеризация С нормализацией ---

# %% [markdown]
# Вычислите силуэтные коэффициенты для оценки качества кластеризации с нормализацией и без нее, как это было сделано в задаче 4 части 1.

# %%
score_ed_raw = silhouette_score(ed_matrix_raw, h_clustering_raw.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент (ED без нормализации): {score_ed_raw:.4f}")


score_ed_norm = silhouette_score(ed_matrix_norm, h_clustering_norm.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент (ED с нормализацией):  {score_ed_norm:.4f}")


pairwise_dtw_raw = PairwiseDistance(metric='dtw', is_normalize=False)
dtw_matrix_raw = pairwise_dtw_raw.calculate(subs_set)

h_clustering_dtw_raw = TimeSeriesHierarchicalClustering(n_clusters=2, method='complete')
h_clustering_dtw_raw.fit(dtw_matrix_raw)

score_dtw_raw = silhouette_score(dtw_matrix_raw, h_clustering_dtw_raw.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент (DTW без нормализации): {score_dtw_raw:.4f}")


pairwise_dtw_norm = PairwiseDistance(metric='dtw', is_normalize=True)
dtw_matrix_norm = pairwise_dtw_norm.calculate(subs_set)

h_clustering_dtw_norm = TimeSeriesHierarchicalClustering(n_clusters=2, method='complete')
h_clustering_dtw_norm.fit(dtw_matrix_norm)

score_dtw_norm = silhouette_score(dtw_matrix_norm, h_clustering_dtw_norm.model.labels_, metric='precomputed')
print(f"Силуэтный коэффициент (DTW с нормализацией):  {score_dtw_norm:.4f}")
# Out:
# Силуэтный коэффициент (ED без нормализации): 0.4183
# Силуэтный коэффициент (ED с нормализацией):  0.4183
# Силуэтный коэффициент (DTW без нормализации): 0.6422
# Силуэтный коэффициент (DTW с нормализацией):  0.6422

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Сравните полученные результаты кластеризации с помощью построенных дендрограмм и вычисленных силуэтных коэффициентов. Позволила ли $z$-нормализации временных рядов повысить качество кластеризации?

# %% [markdown]
# Выбор метрики: DTW мера (0.6422) показала себя значительно эффективнее евклидовой метрики (0.4183) для кластеризации сегментов ЭКГ. Это говорит о том, что ключевым фактором различия между сигналами является их форма и возможные временные деформации, с которыми DTW успешно справляется.
# Влияние Z-нормализации: В данном конкретном случае Z-нормализация не повлияла на итоговое качество кластеризации ни для одной из метрик. Силуэтные коэффициенты остались абсолютно идентичными как с нормализацией, так и без нее. Это указывает на то, что разница в амплитуде между исходными временными рядами не была достаточно существенной, чтобы помешать алгоритмам кластеризации. Основные различия, определяющие структуру кластеров, лежали в области формы и фазовых сдвигов, а не масштаба.

# %% [markdown]
# ## **Часть 3.** Классификация изображений, представленных в виде временных рядов.

# %% [markdown]
# ### **Задача 7.**
# В данном задании вам предстоит выполнить преобразование изображения, на котором находится некоторый объект, во временной ряд. Для этого вы реализуете один из существующих методов, предложенный в [статье Кеога и др](https://dl.acm.org/doi/10.5555/1182635.1164203).
#
# Данный метод заключается в том, что сначала на изображении выполняется поиск контура $E = \{e_i\}_{i=1}^L$, где $e_i$ – точки контура, и центра масс объекта $O$. Затем берутся точки, расположенные на контуре объекта, следующим образом.
#
# Рассмотрим луч $OP$ с началом в центре масс объекта $O$, направление которого совпадает с положительным направлением оси Ox (см. рисунок). Далее выполняется поворот против часовой стрелки луча $OP$ вокруг центра масс $O$ на некоторый заданный угол $α$, $1° \leqslant α \leqslant 360°$. Поворот луча будет осуществляться до тех пор, пока луч не пройдет полный оборот. Все точки $P = \{P_i\}_{i=1}^K$, $P_i \in E$, $K = \lfloor \frac{360°}{α} \rfloor$, образованные пересечением луча $OP$ с контуром $E$ во время поворота, будут являться искомыми.
#
# На завершающем шаге метода вычисляются расстояния между центром масс объекта $O$ и найденными точками на контуре $P$. В качестве функции расстояния может быть использовано манхэттенское или евклидово расстояние. Полученные расстояния будут формировать временной ряд $T$ длины $K$:
# \begin{equation}
# T = \{t_i\}_{i=1}^K,\;где \; t_i = dist(O, P_i), \; P_i \in P.
# \end{equation}
#
# \
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/image2ts.png?raw=true" width="1000"></center>

# %% [markdown]
# Поскольку часть 3 предполагает работу с изображениями, то вы будете использовать для реализации некоторых частей кода библиотеку компьютерного зрения *cv2*. Для поиска всех необходимых функций рекомендуем воспользоваться [документацией библиотеки cv2](https://docs.opencv.org/4.x/d6/d00/tutorial_py_root.html).
#
# Загрузите изображение *example.tif* из директории *./datasets/part3* и выполните его визуализацию с помощью соответствующих функций из библиотеки *cv2*.

# %%
import cv2
import matplotlib.pyplot as plt


img_path = './datasets/part3/example.tif'
img = cv2.imread(img_path)


img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis('on') 
plt.show()

# %% [markdown]
# За конвертацию изображения во временной ряд с помощью описанного выше метода отвечает функция `image2ts()` из модуля *image_converter.py*. Прежде чем исходное изображение будет преобразовано во временной ряд, сначала оно должно пройти этап предварительной обработки. Предварительная обработка включает в себя следующие шаги:
#
# <center><img src="https://github.com/mzym/TimeSeriesCourse/blob/main/practice/01%20Basics/img/image_preprocessing.png?raw=true" width="1000"></center>
#
# Предобработка изображения в `image2ts()` осуществляется с помощью функции `_img_preprocess()`. Реализуйте в данной функции все представленные на диаграмме шаги предварительной обработки средствами библиотеки *cv2*. Промежуточные результаты должны совпадать с представленными на диаграмме.
#
# Далее выполните конвертацию изображения во временной ряд, передав в функцию `image2ts()` следующие заданные вами аргументы:
# *   исходное загруженное изображение;
# *   шаг угла поворота;
# *   параметр, определяющий нужно или нет визуализировать изображение с выделенными на нем контуром, центром масс и лучами, проведенными из центра.
#
# Визуализируйте полученный временной ряд.

# %%
from modules.image_converter import Image2TimeSeries
from modules.plots import plot_ts
import numpy as np 




angle_step = 20  
visualize = True


converter = Image2TimeSeries(angle_step=angle_step)


ts = converter.convert(img, is_visualize=visualize)


fig = plot_ts(np.array([ts]), "Time series representation of image")
fig
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="d61e9976-8151-42d5-82c0-061a497e9627" class="plotly-graph-div" style="height:400px; width:1000px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d61e9976-8151-42d5-82c0-061a497e9627")) {                    Plotly.newPlot(                        "d61e9976-8151-42d5-82c0-061a497e9627",                        [{"line":{"width":3},"name":"Time series 0","x":{"dtype":"i4","bdata":"AAAAAAEAAAACAAAAAwAAAAQAAAAFAAAABgAAAAcAAAAIAAAACQAAAAoAAAALAAAADAAAAA0AAAAOAAAADwAAABAAAAARAAAA"},"y":{"dtype":"f8","bdata":"AAAAAABgckAVe0op0MB2QCm2KV+dR3pAlUlfNad5fkD5ztvmuHR\u002fQLp6YtpO9npARKm135GYdkDfTudjqlF4QK+BmLE1Z3RAH1ktKwbAdECNUtk8GCdwQJuc4sXBHnZAsLKLCQSxc0A\u002fJ26KKMx9QGI2\u002fSQv+IBAhZez\u002fBoMdUAFjqr76pRwQDh7ZuAw8nJA"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"col ...

# %% [markdown]
# ### **Задача 8.**
#
# Выполните классификацию изображений, представленных в виде временных рядов, с помощью метода $k$ ближайших соседей (kNN).
#
# **Метод $k$ ближайших соседей (kNN)** – алгоритм классификации, заключающийся в вычислении сходства между объектами на основе некоторой заданной метрики/меры схожести. Классифицируемый объект относится к тому классу, к которому принадлежит большинство из его $k$ соседей ($k$ ближайших к нему объектов из обучающей выборки).
#
# Для классификации на основе алгоритма kNN необходимо выполнить следующие шаги:
#
# 1. Загрузить обучающую и тестовую выборки.
#
# 2. Задать параметр алгоритма $k$, где $k$ – количество ближайших соседей, $k \in \mathbb N^*$.
#
# 3. Для каждого объекта из тестовой выборки выполнить следующее:
#
#     3.1. Вычислить расстояние до всех объектов из обучающей выборки на основе заданной метрики/меры схожести.
#
#     3.2. Отсортировать в порядке возрастания найденные расстояния.
#
#     3.3. Найти $k$ ближайших соседей, взяв первые $k$ минимальные расстояния из отсортированного массива расстояний.
#
#     3.4. Назначить объекту из тестовой выборки наиболее часто встречающийся класс найденных ранее ближайших соседей.
#
#
# Для этого задания вам предлагается набор данных, который содержит изображения листьев четырех различных пород деревьев: дуб, ольха, ива и липа. Набор данных состоит из обучающей и тестовой выборок, включающих по 15 и 10 изображений листьев на класс соответственно. Для составления этого набора данных изображения были взяты из [Swedish Leaf Dataset](https://www.cvl.isy.liu.se/en/research/datasets/swedish-leaf/).
#
# Загрузите изображения из обучающей и тестовой выборок, а также их метки, используя `read_images()` и `read_ts()` соответственно.
# Выполните визуализацию прецедентов выборки с помощью функции `plot_images()`.

# %%
def read_images(dir: str) -> list[np.ndarray]:
    """
    Load all images from a directory

    Parameters
    ----------
    dir: directory path

    Returns
    -------
    images: images from a directory
    """

    images = []
    for img_path in sorted(glob.glob(dir)):
        cv_img = cv2.imread(img_path)
        images.append(cv_img)

    return images

# %%
def plot_images(images: list[np.ndarray], labels: np.ndarray, class_names: list[str]) -> None:
    """
    Plot some images from dataset

    Parameters
    ----------
    images: dataset of images
    labels: labels of images
    class_names: class names of images
    """

    rows = 2
    columns = 4

    fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*2, rows*3))

    for num in range(1, rows*columns+1):
        fig.add_subplot(rows, columns, num)
        idx = num - 1
        plt.imshow(images[idx], aspect='auto')
        plt.title(f'{class_names[labels[idx]]}', fontsize=10)

    fig.tight_layout()

    for idx, ax in enumerate(axes.flat):
        ax.set_xticks([])
        ax.set_yticks([])

# %%
train_set_path = "./datasets/part3/train_set_leaves/*.tif"
test_set_path = "./datasets/part3/test_set_leaves/*.tif"

train_images = read_images(train_set_path)
test_images = read_images(test_set_path)

train_label_path = './datasets/part3/train_set_leaves/train_label.csv'
test_label_path = './datasets/part3/test_set_leaves/test_label.csv'

train_labels = read_ts(train_label_path)
train_labels = train_labels.reshape(-1).astype('int32')

test_labels = read_ts(test_label_path)
test_labels = test_labels.reshape(-1).astype('int32')
# Out:
# c:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics\modules\utils.py:20: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#
# c:\2025-NAzarchuk-TimeSeriesCourse\practice\01 Basics\modules\utils.py:20: FutureWarning:
#
# The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead

# %%
class_names = ['Quercus (дуб)', 'Alnus (ольха)', 'Salix (ива)', 'Tilia (липа)']
plot_images(train_images, train_labels, class_names)

# %% [markdown]
# Выполните преобразование изображений обучающей и тестовой выборок во временные ряды с помощью функции `image2ts()`.

# %%
converter = Image2TimeSeries(angle_step=5)


train_ts = []
test_ts = []

print("Конвертируем обучающую выборку...")

for img in train_images:
    ts = converter.convert(img)
    train_ts.append(ts)

print("Конвертируем тестовую выборку...")

for img in test_images:
    ts = converter.convert(img)
    test_ts.append(ts)


train_ts = np.array(train_ts)
test_ts = np.array(test_ts)

print(f"\nГотово. Размер обучающей выборки временных рядов: {train_ts.shape}")
print(f"Размер тестовой выборки временных рядов: {test_ts.shape}")
# Out:
# Конвертируем обучающую выборку...
# Конвертируем тестовую выборку...
#
# Готово. Размер обучающей выборки временных рядов: (60, 72)
# Размер тестовой выборки временных рядов: (40, 72)

# %% [markdown]
# Для классификации временных рядов методом $k$ ближайших соседей вам необходимо использовать класс `TimeSeriesKNN` из модуля *classification.py*.
# Реализуйте метод `fit()` в классе `TimeSeriesKNN`, который выполняет поиск для каждого элемента из тестовой выборки $k$ ближайших соседей и назначает им тот класс, который является часто встречающимся среди классов ближайших соседей. В качестве параметров в метод `fit()` передается тестовая выборка. Вычислите точность классификации по метрике accuracy с помощью функции `calculate_accurary()` из модуля *classification.py*.

# %%
n_neighbors = 6
metric = 'euclidean'
metric_params = {'normalize': True}
р
knn_euclidean = TimeSeriesKNN(n_neighbors=n_neighbors, metric=metric, metric_params=metric_params)
knn_euclidean.fit(train_ts, train_labels)


y_pred_euclidean = knn_euclidean.predict(test_ts)


accuracy_euclidean = calculate_accuracy(test_labels, y_pred_euclidean)
print(f"Точность с метрикой '{metric}' (нормализация={metric_params['normalize']}): {accuracy_euclidean:.4f}")
# Out:
# Точность с метрикой 'euclidean' (нормализация=True): 0.5750

# %%
n_neighbors = 6
metric = 'dtw'
metric_params = {'normalize': True}

knn_dtw = TimeSeriesKNN(n_neighbors=n_neighbors, metric=metric, metric_params=metric_params)
knn_dtw.fit(train_ts, train_labels)


y_pred_dtw = knn_dtw.predict(test_ts)


accuracy_dtw = calculate_accuracy(test_labels, y_pred_dtw)
print(f"Точность с метрикой '{metric}' (нормализация={metric_params['normalize']}): {accuracy_dtw:.4f}")
# Out:
# Точность с метрикой 'dtw' (нормализация=True): 0.7750

# %% [markdown]
# ![equation.png](data:image/png;base64,...)
# Проанализируйте результаты и сделайте выводы.

# %% [markdown]
# В ходе выполнения задачи классификации изображений листьев были получены следующие значения точности (accuracy):
# Для метрики euclidean (с нормализацией): 57.5%
# Для метрики DTW (с нормализацией): 77.5%
# Из этих результатов можно сделать вывод, что DTW мера показала значительно более высокую эффективность для данной задачи.
# Причина такого расхождения заключается в природе данных и особенностях метрик. Временные ряды, полученные из контуров листьев, отражают их форму. Листья одного вида имеют схожий паттерн, но из-за естественных вариаций их временные представления могут быть немного растянуты, сжаты или сдвинуты по временной оси.
# Евклидово расстояние очень чувствительно к таким временным деформациям, что приводит к снижению точности классификации.
# DTW (Dynamic Time Warping), напротив, устойчив к таким искажениям, так как находит оптимальное выравнивание между рядами. Это позволяет ему эффективнее определять сходство по форме, что и привело к более высокому результату точности.
# Таким образом, для задач классификации, основанных на форме временного ряда, где возможны временные сдвиги и деформации, DTW является более предпочтительной метрикой, чем евклидово расстояние.
